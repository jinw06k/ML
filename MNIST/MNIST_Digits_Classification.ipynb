# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.datasets import mnist

# %%
(train_X, train_y), (test_X, test_y) = mnist.load_data()

print('X_train: ' + str(train_X.shape))
print('Y_train: ' + str(train_y.shape))
print('X_test:  '  + str(test_X.shape))
print('Y_test:  '  + str(test_y.shape))

img = plt.imshow(train_X[10])
plt.colorbar(img) 
plt.show()
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %%
train_X = train_X/256
test_X = test_X/256

img = plt.imshow(train_X[10])
plt.colorbar(img) 
plt.show()

# %%
import keras
from keras import layers

# %%
model = keras.Sequential(
    [
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128,activation='relu'),
        tf.keras.layers.Dense(128,activation='relu'),
        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.Dense(10,activation='softmax')
    ]
)

# %%
learning_rate_e = 0.001

# %%
model.compile(loss='SparseCategoricalCrossentropy', 
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate_e),
              metrics=['accuracy'])

# %%
model.fit(train_X, train_y, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 914us/step - accuracy: 0.8679 - loss: 0.4316
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 912us/step - accuracy: 0.9695 - loss: 0.1013
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 920us/step - accuracy: 0.9777 - loss: 0.0691

# %%
loss, accuracy =  model.evaluate(test_X, test_y)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - accuracy: 0.9739 - loss: 0.0938

# %%
predictions = model.predict([test_X])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step

# %%
plt.imshow(test_X[0])
plt.show()
print(np.argmax(predictions[0]))
# Out:
# 7

# %%
plt.imshow(test_X[94])
plt.show()
print(np.argmax(predictions[94]))
# Out:
# 1

# %%
plt.imshow(test_X[123])
plt.show()
print(np.argmax(predictions[123]))
# Out:
# 6
